# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
with pd.ExcelFile(r"D:\小鸡理财\百度云同步盘\小鸡理财\数据报告\用户类报告\流失用户分析\流失用户分布.xlsx") as xlsx:
    df_jd_ds = pd.read_excel(xlsx,'经典待收变化')
    df_cg_ds = pd.read_excel(xlsx,'存管待收变化')
    df_vip = pd.read_excel(xlsx,'VIP变动')
    df_tz = pd.read_excel(xlsx,'投资')
    df_members = pd.read_excel(xlsx,'会员列表')

# %%
df_new_member = pd.read_csv(r'D:\小鸡理财\百度云同步盘\小鸡理财\数据报告\用户类报告\流失用户分析\运营数据.txt',
                            delimiter="\t",
                            header=None,
                            engine = 'python',
                            names=['用户名','手机号码','身份证'])

# %% [markdown]
# 确定 经典版待收变化 表的用户对应的存管用户名

# %%
df_jd_ds.dropna(subset=['身份证'],inplace=True)

# %%
df_jd_ds['身份证'] = df_jd_ds['身份证'].str.upper()

# %%
df_new_member['身份证'] = df_new_member['身份证'].str.upper()

# %%
df_temp = pd.merge(df_jd_ds,df_new_member,
                   on = '身份证',
                   how = 'left',
                   suffixes=('_经典', '_存管'))

# %%
df_jd_ds_new = df_temp.loc[df_temp['用户名_存管'].notnull(),:]

# %%
df_jd_ds_new = df_jd_ds_new.loc[:,['真实姓名','待收金额', '发生时间', '注册时间', '身份证', '用户来源','用户名_存管']]

# %% [markdown]
# 合并 经典、存管待收变化 表

# %%
df_jd_ds_new.rename(columns={'用户名_存管':'用户名'},inplace=True)

# %%
df_jd_ds_new.columns
# Out:
# Index(['真实姓名', '待收金额', '发生时间', '注册时间', '身份证', '用户来源', '用户名'], dtype='object')

# %%
df_ds = pd.concat([df_jd_ds_new,df_cg_ds],axis = 0,join='inner')

# %%
df_ds.head()
# Out:
#   真实姓名      待收金额                发生时间                 注册时间                 身份证  \
# 0  王秀珍  41800.00 2018-09-18 09:50:02  2018-01-18 19:04:56  370112198511230029
# 1  徐孟珍  10450.00 2018-09-18 09:50:02  2018-01-17 09:51:01  33021919620422022X
# 2  冯海英  41850.08 2018-09-18 09:50:02  2018-01-09 08:26:39  440106197312094024
# 3  赵世杰  12540.00 2018-09-18 09:50:02  2018-01-06 00:07:28  420624197510072930
# 4   王琼   5226.72 2018-09-18 09:50:02  2018-01-05 11:48:33  330226196304120123
#
#    用户来源                    用户名
# 0  非存管版  XJLC_83710256077e830f
# 1  非存管版  XJLC_70236255704e902e
# 2  非存管版  XJLC_7497125467999005
# 3  非存管版  XJLC_3875625430301af5
# 4  非存管版  XJLC_383062312384ce47

# %%
df_ds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 159758 entries, 0 to 79254
# Data columns (total 7 columns):
# 真实姓名    159758 non-null object
# 待收金额    159758 non-null float64
# 发生时间    159758 non-null datetime64[ns]
# 注册时间    159758 non-null object
# 身份证     159758 non-null object
# 用户来源    159758 non-null object
# 用户名     159758 non-null object
# dtypes: datetime64[ns](1), float64(1), object(5)
# memory usage: 9.8+ MB

# %% [markdown]
# 筛选 待收表 中待收0的用户

# %%
df_ds_0 = df_ds[df_ds['待收金额'] == 0]

# 48442  宋玉棋   0.0 2018-03-05 15:05:02  2015-05-13 12:44:53  330281199301173818
# 48419   陈晓   0.0 2018-03-05 15:05:02  2015-07-02 11:19:46  330225199308010017
#
#        用户来源                  用户名
# 48536  非存管版    XJLC_28242404ccb3
# 48535  非存管版    XJLC_30239417c94e
# 48540  非存管版    XJLC_6576910e6010
# 48526  非存管版    XJLC_1151066cac53
# 48490  非存管版  XJLC_179733714ead16
# 48529  非存管版    XJLC_2019853d7822
# 48454  非存管版  XJLC_224254564f9250
# 48458  非存管版  XJLC_2382944901a386
# 48514  非存管版   XJLC_241754235ff4a
# 48475  非存管版  XJLC_245514233acf7d
# 48460  非存管版  XJLC_2771544773d938
# 48462  非存管版  XJLC_3410944571b0e4
# 48465  非存管版  XJLC_344444408b370b
# 48483  非存管版  XJLC_35243380627f34
# 48448  非存管版  XJLC_35447469459e90
# 48433  非存管版  XJLC_3616662242f3df
# 48506  非存管版   XJLC_3795162232575
# 48424  非存管版  XJLC_43365758608000
# 48417  非存管版  XJLC_437228031d89ed
# 48489  非存管版  XJLC_4470037209e392
# 48456  非存管版  XJLC_464554517e40d7
# 48485  非存管版  XJLC_4900437902eac8
# 48463  非存管版  XJLC_549474446d1ce6
# 48511  非存管版   XJLC_57796490aa14b
# 48487  非存管版  XJLC_5898237741b250
# 48512  非存管版   XJLC_5912548943589
# 48501  非存管版   XJLC_59655748106ce
# 48497  非存管版   XJLC_61795921975ab
# 48442  非存管版  XJLC_6214949124fb40
# 48419  非存管版  XJLC_6444580124ed29

# %% [markdown]
# 查看 在待收变0 后是否还有投资，记录投资金额、投资时间

# %%
df_tz.sort_values(by=['投资时间','用户名'],ascending=True,inplace=True)

# %%
df_tz.head(30)
# Out:
#                          用户名 真实姓名         手机号码               身份证号码  \
# 18154   XJLC_30909579286b935  王惠英  15384149920  330622196611042221
# 18153     XJLC_130871071786e  席翔峰  15857443323  622101195502250758
# 18152  XJLC_89216200938703f8   韦卓  13772150570  610115198403175025
# 31087  XJLC_959651459155965c  涂玉群  13650519385  510282198111152720
# 18151  XJLC_23512231321d1f30  周雪梅  13957832139  330204198212036021
# 18150  XJLC_23512231321d1f30  周雪梅  13957832139  330204198212036021
# 18149  XJLC_5681513924302484  孙秀刚  13516349580  370919196103030916
# 18148  XJLC_23512231321d1f30  周雪梅  13957832139  330204198212036021
# 31086    XJLC_744438970ef8f5  张慧慧  18458696590  341202199105253121
# 31085  XJLC_23512231321d1f30  周雪梅  13957832139  330204198212036021
# 18147  XJLC_78812231165cf4b8  白忠民  13863474855  610103196709302897
# 18146  XJLC_9926616188771c5a  蔡立新  13382297919  320281196606168512
# 18145  XJLC_25523140594220e3   朱芳  13567905122  330211196306290746
# 18144  XJLC_940082313150bc80  王正平  18942983051  421002197706152916
# 18143  XJLC_7509316587121fd3   徐琴  18663406153  371203196408200324
# 31084  XJLC_59928231244dd144   马超  15210275607  230106198506161219
# 31083  XJLC_20104146410bce86  陈文珠  15057400849  330203195211150025
# 18136        2017-02-21  12月   8000.0 2018-03-01 13:43:48   安卓端
# 18135        2017-08-22  12月   3000.0 2018-03-01 13:45:04   安卓端
# 31079  2017-03-09 11:02   3月  13000.0 2018-03-01 13:45:48   苹果端
# 31078  2015-12-21 21:04   3月  10500.0 2018-03-01 13:52:05   苹果端

# %%
df_ds_0.dtypes
# Out:
# 真实姓名            object
# 待收金额           float64
# 发生时间    datetime64[ns]
# 注册时间            object
# 身份证             object
# 用户来源            object
# 用户名             object
# dtype: object

# %%
df_tz.dtypes
# Out:
# 用户名              object
# 真实姓名             object
# 手机号码              int64
# 身份证号码            object
# 注册时间             object
# 计划期限             object
# 总投资金额           float64
# 投资时间     datetime64[ns]
# 投资来源             object
# dtype: object

# %%
df_0_invest = pd.merge_asof(df_ds_0,df_tz,
             by = '用户名',
             left_on = '发生时间',
             right_on = '投资时间',
             direction='forward')

# %%
df_0_invest.shape
# Out:
# (6018, 15)

# %% [markdown]
# 待收0后的再投资时间间隔

# %%
df_0_invest.columns
# Out:
# Index(['真实姓名_x', '待收金额', '发生时间', '注册时间_x', '身份证', '用户来源', '用户名', '真实姓名_y',
#        '手机号码', '身份证号码', '注册时间_y', '计划期限', '总投资金额', '投资时间', '投资来源'],
#       dtype='object')

# %%
df_reinvest = df_0_invest.loc[df_0_invest['投资时间'].notnull(),['真实姓名_x',
                                                             '待收金额', 
                                                             '发生时间', 
                                                             '注册时间_x', 
                                                             '身份证', 
                                                             '用户来源', 
                                                             '用户名',
                                                             '手机号码', 
                                                             '计划期限', 
                                                             '总投资金额', 
                                                             '投资时间', 
                                                             '投资来源']]

# %%
df_reinvest.head(30)
# Out:
#     真实姓名_x  待收金额                发生时间               注册时间_x                 身份证  \
# 4      黄玉莹   0.0 2018-03-05 15:05:02  2014-12-14 23:35:08  452701197010210047
# 10     陈宽鸿   0.0 2018-03-05 15:05:02  2015-03-25 08:57:38  511021199003056119
# 13      李丽   0.0 2018-03-05 15:05:02  2014-12-17 14:43:24  420983198901023643
# 26      戴娜   0.0 2018-03-05 15:05:02  2014-10-30 19:12:51  330227198310157526
# 35     邹种华   0.0 2018-03-05 15:05:02  2015-01-13 14:26:50  330501199111103311
# 57     张永圣   0.0 2018-03-05 15:05:03  2015-09-19 18:00:24  342423197205177036
# 65     戴姣娆   0.0 2018-03-05 15:05:03  2015-09-14 15:34:47  330211197310250020
# 69     任丽娟   0.0 2018-03-05 15:05:03  2015-08-05 15:23:41  330621199401318709
# 70     范光琳   0.0 2018-03-05 15:05:03  2015-09-14 16:07:18  330226198008316075
# 81     贾建国   0.0 2018-03-05 15:05:04  2015-10-03 11:57:44  372901198307156833
# 82      何颖   0.0 2018-03-05 15:05:04  2015-10-11 19:01:22  330719198307016367
# 85     钱璋辉   0.0 2018-03-05 15:05:04  2015-10-14 08:31:36  330225198602274019
# 87     李瑞菊   0.0 2018-03-05 15:05:04  2015-10-03 11:57:47  372930198008145968
# 103  非存管版  XJLC_796582775923a6a  1.360584e+10   6月    1000.0
# 105  非存管版  XJLC_874943767567e5e  1.575786e+10  12月    5000.0
# 109  非存管版  XJLC_96613376807c90d  1.596849e+10   6月     100.0
# 113  非存管版  XJLC_134795090935b4c  1.890663e+10  12月    1000.0
# 115  非存管版  XJLC_2735552089ca118  1.598802e+10   6月    4400.0
# 125  非存管版  XJLC_598834132565324  1.865846e+10   3月  100000.0
# 127  非存管版  XJLC_6750756184fb6fa  1.373881e+10   6月     100.0
# 140  非存管版  XJLC_10002710842e492  1.586937e+10   6月     200.0
# 150  非存管版  XJLC_32958711079bc27  1.348650e+10   1月     100.0
# 156  非存管版  XJLC_5155870063bf217  1.865841e+10   6月     300.0
# 157  非存管版  XJLC_5165172357fe925  1.317516e+10   3月    3000.0
# 169  非存管版  XJLC_931037103446f92  1.342926e+10   3月     100.0
#
#                    投资时间 投资来源
# 4   2018-08-21 10:06:54  安卓端
# 10  2018-07-12 18:15:17  苹果端
# 13  2018-06-13 21:08:28  苹果端
# 26  2018-03-06 17:22:32  安卓端
# 35  2018-03-06 00:45:50  安卓端
# 57  2018-03-06 08:35:18  安卓端
# 65  2018-04-29 10:30:48  苹果端
# 69  2018-04-23 15:14:47  苹果端
# 70  2018-03-09 16:48:52  微信端
# 81  2018-03-27 17:57:05  苹果端
# 82  2018-05-08 09:56:30  苹果端
# 85  2018-04-24 16:55:07  安卓端
# 87  2018-06-16 15:48:10  苹果端
# 89  2018-07-05 22:43:40  苹果端
# 90  2018-04-29 11:57:17  苹果端
# 93  2018-03-07 17:15:09  微信端
# 99  2018-04-04 19:54:18  苹果端
# 102 2018-04-04 09:03:32  微信端
# 103 2018-05-04 06:42:30  苹果端
# 105 2018-03-09 10:04:31  微信端
# 109 2018-04-03 16:22:50  微信端
# 113 2018-04-27 10:33:10  苹果端
# 115 2018-04-04 15:47:36  苹果端
# 125 2018-05-19 10:06:50  苹果端
# 127 2018-03-06 19:59:31  安卓端
# 140 2018-05-03 10:38:33  苹果端
# 150 2018-08-07 17:44:54  苹果端
# 156 2018-07-14 17:52:51  微信端
# 157 2018-08-01 21:36:21  苹果端
# 169 2018-04-23 15:09:04  苹果端

# %%
time_gap = (df_reinvest['投资时间'] - df_reinvest['发生时间']).dt.days

# %%
type(time_gap)
# Out:
# pandas.core.series.Series

# %%
time_gap.shape
# Out:
# (1751,)

# %%
time_gap.head()
# Out:
# 4     168
# 10    129
# 13    100
# 26      1
# 35      0
# dtype: int64

# %%
time_gap_percent = time_gap.value_counts(normalize = True)

# %%
time_gap_counts = time_gap.value_counts()

# %%
time_gap_frequence = pd.concat([time_gap_counts,time_gap_percent],axis=1)

# %%
time_gap_frequence.rename(columns={0:'counts',1:'freq'},inplace=True)

# %%
time_gap_frequence.sort_index(inplace=True)

# %%
time_gap_frequence.head(30)
# Out:
#     counts      freq
# 0      478  0.272987
# 1      114  0.065106
# 2       81  0.046259
# 3       77  0.043975
# 4       56  0.031982
# 5       66  0.037693
# 6       42  0.023986
# 7       32  0.018275
# 8       38  0.021702
# 9       41  0.023415
# 10      20  0.011422
# 11      24  0.013706
# 12      19  0.010851
# 13      16  0.009138
# 14      16  0.009138
# 15      19  0.010851
# 16      25  0.014278
# 17      23  0.013135
# 18      16  0.009138
# 19      14  0.007995
# 20      15  0.008567
# 21      18  0.010280
# 22      18  0.010280
# 23      11  0.006282
# 24      11  0.006282
# 25       8  0.004569
# 26       8  0.004569
# 27      11  0.006282
# 28       8  0.004569
# 29      12  0.006853

# %%
type(time_gap_frequence)
# Out:
# pandas.core.frame.DataFrame

# %%
time_gap_frequence['freq_cum'] = time_gap_frequence['freq'].cumsum()

# %%
time_gap_frequence.head(30)
# Out:
#     counts      freq  freq_cum
# 0      478  0.272987  0.272987
# 1      114  0.065106  0.338093
# 2       81  0.046259  0.384352
# 3       77  0.043975  0.428327
# 4       56  0.031982  0.460308
# 5       66  0.037693  0.498001
# 6       42  0.023986  0.521987
# 7       32  0.018275  0.540263
# 8       38  0.021702  0.561965
# 9       41  0.023415  0.585380
# 10      20  0.011422  0.596802
# 11      24  0.013706  0.610508
# 12      19  0.010851  0.621359
# 13      16  0.009138  0.630497
# 14      16  0.009138  0.639634
# 15      19  0.010851  0.650485
# 16      25  0.014278  0.664763
# 17      23  0.013135  0.677898
# 18      16  0.009138  0.687036
# 19      14  0.007995  0.695031
# 20      15  0.008567  0.703598
# 21      18  0.010280  0.713878
# 22      18  0.010280  0.724158
# 23      11  0.006282  0.730440
# 24      11  0.006282  0.736722
# 25       8  0.004569  0.741291
# 26       8  0.004569  0.745860
# 27      11  0.006282  0.752142
# 28       8  0.004569  0.756710
# 29      12  0.006853  0.763564

# %%
plt.figure(figsize=(16,12), dpi=160)
# width = .35 # width of a bar

time_gap_frequence['counts'].plot(kind='bar')
time_gap_frequence['freq_cum'].plot(secondary_y=True)

ax = plt.gca()
plt.xlim(0,60)

plt.show()

# %% [markdown]
# 结论：
#
# 1、待收变0后的第30天起没有再投资转为流失用户
#
# 2、待收变0后的第30天起又有投资，即转为激活用户

# %% [markdown]
# ### 流失用户分析

# %% [markdown]
# 流失用户有哪些

# %%
timediff = pd.Timedelta(30,unit = 'd')

# %%
df_0_invest['流失时间'] = df_0_invest['发生时间'] + timediff

# %%
df_0_invest.head()
# Out:
#   真实姓名_x  待收金额                发生时间               注册时间_x                 身份证  \
# 0    姚露露   0.0 2018-03-05 15:05:01  2014-09-03 08:45:07  330902199201252925
# 1    李雪燕   0.0 2018-03-05 15:05:01  2014-09-03 08:47:22  330227199210311500
# 2    黄振兴   0.0 2018-03-05 15:05:01  2014-09-02 20:53:14  620121198702155330
# 3    项晶晶   0.0 2018-03-05 15:05:02  2014-09-03 10:16:08  342422198710110869
# 4    黄玉莹   0.0 2018-03-05 15:05:02  2014-12-14 23:35:08  452701197010210047
#
#    用户来源                  用户名 真实姓名_y          手机号码               身份证号码  \
# 0  非存管版    XJLC_28242404ccb3    NaN           NaN                 NaN
# 1  非存管版    XJLC_30239417c94e    NaN           NaN                 NaN
# 2  非存管版    XJLC_6576910e6010    NaN           NaN                 NaN
# 3  非存管版    XJLC_1151066cac53    NaN           NaN                 NaN
# 4  非存管版  XJLC_179733714ead16    黄玉莹  1.890779e+10  452701197010210047
#
#        注册时间_y 计划期限  总投资金额                投资时间 投资来源                流失时间
# 0         NaN  NaN    NaN                 NaT  NaN 2018-04-04 15:05:01
# 1         NaN  NaN    NaN                 NaT  NaN 2018-04-04 15:05:01
# 2         NaN  NaN    NaN                 NaT  NaN 2018-04-04 15:05:01
# 3         NaN  NaN    NaN                 NaT  NaN 2018-04-04 15:05:02
# 4  2014-12-14   1月  100.0 2018-08-21 10:06:54  安卓端 2018-04-04 15:05:02

# %%
df_0_invest.columns
# Out:
# Index(['真实姓名_x', '待收金额', '发生时间', '注册时间_x', '身份证', '用户来源', '用户名', '真实姓名_y',
#        '手机号码', '身份证号码', '注册时间_y', '计划期限', '总投资金额', '投资时间', '投资来源', '流失时间'],
#       dtype='object')

# %%
df_gone = df_0_invest.loc[(df_0_invest['投资时间'] > df_0_invest['流失时间']) | (df_0_invest['投资时间'].isnull()),['真实姓名_x', '发生时间', '注册时间_x', '身份证', '用户来源', '用户名', '流失时间']]

# %%
# 流失时间在2018-9-1之前
df_gone = df_gone.loc[df_gone['流失时间']<'2018-9-1',:]

# %%
df_gone.head()
# Out:
#   真实姓名_x                发生时间               注册时间_x                 身份证  用户来源  \
# 0    姚露露 2018-03-05 15:05:01  2014-09-03 08:45:07  330902199201252925  非存管版
# 1    李雪燕 2018-03-05 15:05:01  2014-09-03 08:47:22  330227199210311500  非存管版
# 2    黄振兴 2018-03-05 15:05:01  2014-09-02 20:53:14  620121198702155330  非存管版
# 3    项晶晶 2018-03-05 15:05:02  2014-09-03 10:16:08  342422198710110869  非存管版
# 4    黄玉莹 2018-03-05 15:05:02  2014-12-14 23:35:08  452701197010210047  非存管版
#
#                    用户名                流失时间
# 0    XJLC_28242404ccb3 2018-04-04 15:05:01
# 1    XJLC_30239417c94e 2018-04-04 15:05:01
# 2    XJLC_6576910e6010 2018-04-04 15:05:01
# 3    XJLC_1151066cac53 2018-04-04 15:05:02
# 4  XJLC_179733714ead16 2018-04-04 15:05:02

# %%
df_gone.shape
# Out:
# (4281, 7)

# %%
df_gone.nunique()
# Out:
# 真实姓名_x    3859
# 发生时间       739
# 注册时间_x    3928
# 身份证       3927
# 用户来源         2
# 用户名       3929
# 流失时间       739
# dtype: int64

# %% [markdown]
# 哪个月流失最严重

# %%
gp_gone_month = df_gone.resample('M',on='发生时间')['用户名'].nunique()

# %%
gp_gone_month
# Out:
# 发生时间
# 2018-03-31    2607
# 2018-04-30     488
# 2018-05-31     340
# 2018-06-30     271
# 2018-07-31     311
# 2018-08-31       8
# Freq: M, Name: 用户名, dtype: int64

# %%
gp_gone_month.plot.barh()
