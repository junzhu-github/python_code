# %% [markdown]
# ### 导入库

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# 设置中文

# %% [markdown]
# ### 导入excel

# %%
with pd.ExcelFile(r'D:\小鸡理财\百度云同步盘\小鸡理财\数据报告\月报\9月\9月ppt数据.xlsx') as xlsx:
    df_zc = pd.read_excel(xlsx,'注册')
#     df_tz = pd.read_excel(xlsx,'投资')
#     df_yj = pd.read_excel(xlsx,'佣金')
#     df_vip = pd.read_excel(xlsx,'VIP变动')
#     df_quan = pd.read_excel(xlsx,'券')
#     df_zht = pd.read_excel(xlsx,'智慧投')

# %%
df_zc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 246290 entries, 0 to 246289
# Data columns (total 11 columns):
# 用户名         246290 non-null object
# 真实姓名        143430 non-null object
# 邀请人         117555 non-null float64
# 手机号码        246068 non-null float64
# 所属公司        2368 non-null object
# 注册时间        246290 non-null datetime64[ns]
# 归属地         246290 non-null object
# 注册来源        246288 non-null object
# 渠道          246242 non-null object
# new_邀请渠道    246290 non-null object
# 身份证         143162 non-null object
# dtypes: datetime64[ns](1), float64(2), object(8)
# memory usage: 20.7+ MB

# %%
df_zc.head()
# Out:
#                      用户名 真实姓名           邀请人          手机号码 所属公司  \
# 0  XJLC_261422309449bd79  毛郑娜  1.570690e+10  1.895822e+10  NaN
# 1  XJLC_411712295667c664  朱坤强           NaN  1.760659e+10  NaN
# 2  XJLC_6631820535086ec5  王志敏  1.800130e+10  1.369317e+10  NaN
# 3  XJLC_95531205349fba26   王静           NaN  1.880064e+10  NaN
# 4  XJLC_573842053485020c  NaN           NaN  1.776496e+10  NaN
#
#                  注册时间           归属地     注册来源    渠道 new_邀请渠道  \
# 0 2017-07-07 20:04:18    中国  浙江         手机H5    平台     业务邀请
# 1 2017-07-25 08:36:35  中国  河南  商丘    Android  锤子应用     自主注册
# 2 2017-08-08 23:51:41  中国  北京  北京       手机H5  上海凝霜     普通邀请
# 3 2017-08-08 23:50:50  中国  江苏  宿迁    Android  小米商店     推广渠道
# 4 2017-08-08 23:40:39    中国  四川         手机H5    推啊     自主注册
#
#                   身份证
# 0  330283198809043721
# 1  41142519980321211x
# 2  110105195601190045
# 3  321302199104130367
# 4                 NaN

# %%
df_zc_2018 = df_zc.copy()

# %%
df_zc_2018 = df_zc_2018[df_zc_2018['注册时间'].dt.year == 2018]

# %%
df_zc_2018.head()
# Out:
#                           用户名 真实姓名           邀请人          手机号码 所属公司  \
# 107573  XJLC_151492684072f6e2  NaN  1.899160e+10  1.780916e+10  NaN
# 107574  XJLC_67913268406f1a2a  NaN  1.381943e+10  1.865748e+10  NaN
# 107575  XJLC_58860268405536dc  NaN  1.314700e+10  1.581428e+10  NaN
# 107576  XJLC_1522326840334a45  NaN  1.885792e+10  1.373619e+10  NaN
# 107577  XJLC_62045268402bca7b  NaN  1.885792e+10  1.360062e+10  NaN
#
#                       注册时间           归属地 注册来源  渠道 new_邀请渠道  身份证
# 107573 2018-05-23 22:01:54  中国  陕西  汉中     微信  平台     普通邀请  NaN
# 107574 2018-05-23 21:28:10  中国  浙江  宁波     微信  平台     普通邀请  NaN
# 107575 2018-05-23 21:12:33  中国  广东  深圳     微信  平台     普通邀请  NaN
# 107576 2018-05-23 20:29:31    中国  浙江       微信  平台     业务邀请  NaN
# 107577 2018-05-23 20:29:12    中国  浙江       微信  平台     业务邀请  NaN

# %%
gp_zc_month = df_zc_2018.resample('M',on ='注册时间')['用户名'].count()

# %%
type(gp_zc_month)
# Out:
# pandas.core.series.Series

# %%
gp_zc_month.index.strftime('%Y-%m')
# Out:
# Index(['2018-01', '2018-02', '2018-03', '2018-04', '2018-05', '2018-06',
#        '2018-07', '2018-08', '2018-09'],
#       dtype='object')

# %%
f, axes = plt.subplots(1, 1, figsize=(18,9))
sns.barplot(x=gp_zc_month.index.strftime('%Y-%m'), 
            y=gp_zc_month.values)

# %%
sns.set()
tips = sns.load_dataset("tips")
sns.relplot(x="total_bill", y="tip", col="time",
            hue="smoker", style="smoker", size="size",
            data=tips);

# %%
sns.set(style="ticks", palette="bright")
sns.relplot(x="total_bill", y="tip", col="time",
            hue="smoker", style="smoker", size="size",
            data=tips);

# %%
dots = sns.load_dataset("dots")
sns.relplot(x="time", y="firing_rate", col="align",
            hue="choice", size="coherence", style="choice",
            facet_kws=dict(sharex=False),
            kind="line", legend="full", data=dots);

# %%
f, axes = plt.subplots(1, 2, sharey=True, figsize=(18,9))
sns.boxplot(x="day", y="tip", data=tips, ax=axes[0])
sns.scatterplot(x="total_bill", y="tip", hue="day", data=tips, ax=axes[1]);

# %%
iris = sns.load_dataset("iris")
sns.jointplot(x="sepal_length", y="petal_length", data=iris);

# %%
sns.pairplot(data=iris, hue="species");
