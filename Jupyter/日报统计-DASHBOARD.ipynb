# %%
import IPython.core.display as di

# This line will hide code by default when the notebook is exported as HTML
di.display_html('<script>jQuery(function() {if (jQuery("body.notebook_app").length == 0) { jQuery(".input_area").toggle(); jQuery(".prompt").toggle();}});</script>', raw=True)
# Out:
# <script>jQuery(function() {if (jQuery("body.notebook_app").length == 0) { jQuery(".input_area").toggle(); jQuery(".prompt").toggle();}});</script>

# %%
#coding=utf-8
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from pyecharts import online
from pyecharts import Bar
# %matplotlib inline
online()

# %%
os.chdir('D:\OneDrive\python\data')

# %%
with pd.ExcelFile('注册.xlsx') as xlsx:
    df_zhuce = pd.read_excel(xlsx,'注册')
    df_kaitong = pd.read_excel(xlsx,'开通')
    df_touzi = pd.read_excel(xlsx,'投资')

# %%
df_zhuce['注册日期'] = pd.to_datetime(df_zhuce['注册时间']).dt.strftime('%m-%d')

# %%
zhuce_num = df_zhuce.groupby('注册日期')['用户名'].count()

# %% [markdown]
# # 一、注册统计

# %% [markdown]
# # 1.注册人数

# %%
attr = zhuce_num.index
v1 = zhuce_num.values
bar = Bar("每日注册","2018-08")
bar.add('注册人数',attr,v1,mark_line=["average"],mark_point=["max", "min"])
bar
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': 'https://pyecharts.github.io/jupyter-echarts/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="fb0b93705e814b38860ffeae6a6decd1" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_fb0b93705e814b38860ffeae6a6decd1 = echarts.init(document.getElementById('fb0b93705e814b38860ffeae6a6decd1'), 'light', {renderer: 'canvas'});
#
# var option_fb0b93705e814b38860ffeae6a6decd1 = {
#     "title": [
#         {
#             "text": "\u6bcf\u65e5\u6ce8\u518c",
#             "subtext": "2018-08",
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "\u4e0b\u8f7d\u56fe\u7247"
#             },
#             "restore": {
#                 "show": true
#             },
#             "dataView": {
#                 "show": true
#             }
#         }
#     },
#     "series_id": 1486286,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "borderWidth": 0
#     },
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u6ce8\u518c\u4eba\u6570",
#             "data": [
#                 49.0,
#                 25.0,
#                 49.0,
#                 38.0,
#                 26.0,
#                 48.0,
#                 81.0,
#                 108.0,
#                 58.0,
#                 56.0,
#                 32.0,
#                 54.0,
#                 79.0,
#                 130.0,
#                 53.0
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "normal": {
#                     "show": false,
#                     "position": "top",
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "markPoint": {
#                 "data": [
#                     {
#                         "type": "max",
#                         "name": "Maximum",
#                         "symbol": "pin",
#                         "symbolSize": 50,
#                         "label": {
#                             "normal": {
#                                 "textStyle": {
#                                     "color": "#fff"
#                                 }
#                             }
#                         }
#                     },
#                     {
#                         "type": "min",
#                         "name": "Minimum",
#                         "symbol": "pin",
#                         "symbolSize": 50,
#                         "label": {
#                             "normal": {
#                                 "textStyle": {
#                                     "color": "#fff"
#                                 }
#                             }
#                         }
#                     }
#                 ]
#             },
#             "markLine": {
#                 "data": [
#                     {
#                         "type": "average",
#                         "name": "mean-Value"
#                     }
#                 ],
#                 "symbolSize": 10
#             },
#             "seriesId": 1486286
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u6ce8\u518c\u4eba\u6570"
#             ],
#             "selectedMode": "multiple",
#             "show": true,
#             "left": "center",
#             "top": "top",
#             "orient": "horizontal",
#             "textStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "xAxis": [
#         {
#             "show": true,
#             "nameLocation": "middle",
#             "nameGap": 25,
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "inverse": false,
#             "boundaryGap": true,
#             "type": "category",
#             "splitLine": {
#                 "show": false
#             },
#             "axisLine": {
#                 "lineStyle": {
#                     "width": 1
#                 }
#             },
#             "axisLabel": {
#                 "interval": "auto",
#                 "rotate": 0,
#                 "margin": 8,
#                 "textStyle": {
#                     "fontSize": 12
#                 }
#             },
#             "data": [
#                 "08-01",
#                 "08-02",
#                 "08-03",
#                 "08-04",
#                 "08-05",
#                 "08-06",
#                 "08-07",
#                 "08-08",
#                 "08-09",
#                 "08-10",
#                 "08-11",
#                 "08-12",
#                 "08-13",
#                 "08-14",
#                 "08-15"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "nameLocation": "middle",
#             "nameGap": 25,
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "inverse": false,
#             "boundaryGap": true,
#             "type": "value",
#             "splitLine": {
#                 "show": true
#             },
#             "axisLine": {
#                 "lineStyle": {
#                     "width": 1
#                 }
#             },
#             "axisLabel": {
#                 "interval": "auto",
#                 "formatter": "{value} ",
#                 "rotate": 0,
#                 "margin": 8,
#                 "textStyle": {
#                     "fontSize": 12
#                 }
#             }
#         }
#     ],
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597",
#         "#f6f5ec"
#     ]
# };
# myChart_fb0b93705e814b38860ffeae6a6decd1.setOption(option_fb0b93705e814b38860ffeae6a6decd1);
#
#     });
# </script>

# %%
zhuce_num.unstack()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-16-14a50bcfc604> in <module>()
# ----> 1 zhuce_num.unstack()
#
# ~\Anaconda3\lib\site-packages\pandas\core\series.py in unstack(self, level, fill_value)
#    2895         """
#    2896         from pandas.core.reshape.reshape import unstack
# -> 2897         return unstack(self, level, fill_value)
#    2898
#    2899     # ----------------------------------------------------------------------
#
# ~\Anaconda3\lib\site-packages\pandas\core\reshape\reshape.py in unstack(obj, level, fill_value)
#     493         unstacker = _Unstacker(obj.values, obj.index, level=level,
#     494                                fill_value=fill_value,
# --> 495                                constructor=obj._constructor_expanddim)
#     496         return unstacker.get_result()
#     497
#
# ~\Anaconda3\lib\site-packages\pandas\core\reshape\reshape.py in __init__(self, values, index, level, value_columns, fill_value, constructor)
#     114             raise ValueError('must pass column labels for multi-column data')
#     115
# --> 116         self.index = index.remove_unused_levels()
#     117
#     118         self.level = self.index._get_level_number(level)
#
# AttributeError: 'Index' object has no attribute 'remove_unused_levels'

# %% [markdown]
# ## 2、各邀请渠道注册人数

# %%
s_yw = df_zhuce[df_zhuce['邀请渠道'] == '业务邀请'].groupby('注册日期')['用户名'].count()
s_pt = df_zhuce[df_zhuce['邀请渠道'] == '普通邀请'].groupby('注册日期')['用户名'].count()
s_zz = df_zhuce[df_zhuce['邀请渠道'] == '自主注册'].groupby('注册日期')['用户名'].count()

# %%
df_yw = pd.DataFrame(s_yw,index=zhuce_num.index).fillna(0)
df_pt = pd.DataFrame(s_pt,index=zhuce_num.index).fillna(0)
df_zz = pd.DataFrame(s_zz,index=zhuce_num.index).fillna(0)

# %%
attr = zhuce_num.index
v1 = df_yw['用户名']
v2 = df_pt['用户名']
v3 = df_zz['用户名']

bar = Bar("8月注册数","按邀请渠道统计")
bar.add('业务邀请',attr,v1,mark_line=["average"],mark_point=["max", "min"])
bar.add('普通邀请',attr,v2,mark_line=["average"],mark_point=["max", "min"])
bar.add('自主注册',attr,v3,mark_line=["average"],mark_point=["max", "min"])
bar
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': 'https://pyecharts.github.io/jupyter-echarts/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="98a9d5da005a49ec8be92cddeb785efa" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_98a9d5da005a49ec8be92cddeb785efa = echarts.init(document.getElementById('98a9d5da005a49ec8be92cddeb785efa'), 'light', {renderer: 'canvas'});
#
# var option_98a9d5da005a49ec8be92cddeb785efa = {
#     "title": [
#         {
#             "text": "8\u6708\u6ce8\u518c\u6570",
#             "subtext": "\u6309\u9080\u8bf7\u6e20\u9053\u7edf\u8ba1",
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "\u4e0b\u8f7d\u56fe\u7247"
#             },
#             "restore": {
#                 "show": true
#             },
#             "dataView": {
#                 "show": true
#             }
#         }
#     },
#     "series_id": 4618562,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "borderWidth": 0
#     },
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u4e1a\u52a1\u9080\u8bf7",
#             "data": [
#                 37.0,
#                 13.0,
#                 44.0,
#                 29.0,
#                 16.0,
#                 37.0,
#                 64.0,
#                 98.0,
#                 43.0,
#                 51.0,
#                 24.0,
#                 45.0,
#                 68.0,
#                 119.0,
#                 40.0
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "normal": {
#                     "show": false,
#                     "position": "top",
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "markPoint": {
#                 "data": [
#                     {
#                         "type": "max",
#                         "name": "Maximum",
#                         "symbol": "pin",
#                         "symbolSize": 50,
#                         "label": {
#                             "normal": {
#                                 "textStyle": {
#                                     "color": "#fff"
#                                 }
#                             }
#                         }
#                     },
#                     {
#                         "type": "min",
#                         "name": "Minimum",
#                         "symbol": "pin",
#                         "symbolSize": 50,
#                         "label": {
#                             "normal": {
#                                 "textStyle": {
#                                     "color": "#fff"
#                                 }
#                             }
#                         }
#                     }
#                 ]
#             },
#             "markLine": {
#                 "data": [
#                     {
#                         "type": "average",
#                         "name": "mean-Value"
#                     }
#                 ],
#                 "symbolSize": 10
#             },
#             "seriesId": 4618562
#         },
#         {
#             "type": "bar",
#             "name": "\u666e\u901a\u9080\u8bf7",
#             "data": [
#                 2.0,
#                 4.0,
#                 0.0,
#                 2.0,
#                 2.0,
#                 2.0,
#                 9.0,
#                 3.0,
#                 4.0,
#                 0.0,
#                 3.0,
#                 0.0,
#                 1.0,
#                 2.0,
#                 1.0
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "normal": {
#                     "show": false,
#                     "position": "top",
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "markPoint": {
#                 "data": [
#                     {
#                         "type": "max",
#                         "name": "Maximum",
#                         "symbol": "pin",
#                         "symbolSize": 50,
#                         "label": {
#                             "normal": {
#                                 "textStyle": {
#                                     "color": "#fff"
#                                 }
#                             }
#                         }
#                     },
#                     {
#                         "type": "min",
#                         "name": "Minimum",
#                         "symbol": "pin",
#                         "symbolSize": 50,
#                         "label": {
#                             "normal": {
#                                 "textStyle": {
#                                     "color": "#fff"
#                                 }
#                             }
#                         }
#                     }
#                 ]
#             },
#             "markLine": {
#                 "data": [
#                     {
#                         "type": "average",
#                         "name": "mean-Value"
#                     }
#                 ],
#                 "symbolSize": 10
#             },
#             "seriesId": 4618562
#         },
#         {
#             "type": "bar",
#             "name": "\u81ea\u4e3b\u6ce8\u518c",
#             "data": [
#                 10.0,
#                 8.0,
#                 5.0,
#                 7.0,
#                 8.0,
#                 9.0,
#                 8.0,
#                 7.0,
#                 11.0,
#                 5.0,
#                 5.0,
#                 9.0,
#                 10.0,
#                 9.0,
#                 12.0
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "normal": {
#                     "show": false,
#                     "position": "top",
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "markPoint": {
#                 "data": [
#                     {
#                         "type": "max",
#                         "name": "Maximum",
#                         "symbol": "pin",
#                         "symbolSize": 50,
#                         "label": {
#                             "normal": {
#                                 "textStyle": {
#                                     "color": "#fff"
#                                 }
#                             }
#                         }
#                     },
#                     {
#                         "type": "min",
#                         "name": "Minimum",
#                         "symbol": "pin",
#                         "symbolSize": 50,
#                         "label": {
#                             "normal": {
#                                 "textStyle": {
#                                     "color": "#fff"
#                                 }

# %% [markdown]
# # 二、投资统计

# %%
with pd.ExcelFile('投资.xlsx') as xlsx:
    df_touzi = pd.read_excel(xlsx,'投资记录')

# %%
df_touzi['投资日期'] = pd.to_datetime(df_touzi['投资时间']).dt.strftime('%m-%d')

# %%
touzi_money = df_touzi.groupby('投资日期')['总投资金额'].sum()

# %%
attr = touzi_money.index
v1 = touzi_money.values
bar = Bar("每日投资","2018-08")
bar.add('投资金额',attr,v1,mark_line=["average"],mark_point=["max", "min"])
bar
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': 'https://pyecharts.github.io/jupyter-echarts/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="44d3c567d14443819843cef30fd7c4f3" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_44d3c567d14443819843cef30fd7c4f3 = echarts.init(document.getElementById('44d3c567d14443819843cef30fd7c4f3'), 'light', {renderer: 'canvas'});
#
# var option_44d3c567d14443819843cef30fd7c4f3 = {
#     "title": [
#         {
#             "text": "\u6bcf\u65e5\u6295\u8d44",
#             "subtext": "2018-08",
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "\u4e0b\u8f7d\u56fe\u7247"
#             },
#             "restore": {
#                 "show": true
#             },
#             "dataView": {
#                 "show": true
#             }
#         }
#     },
#     "series_id": 3622909,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "borderWidth": 0
#     },
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u6295\u8d44\u91d1\u989d",
#             "data": [
#                 1262300.0,
#                 1718400.0,
#                 1334200.0,
#                 1002200.0,
#                 852100.0,
#                 1232500.0,
#                 2172500.0,
#                 2143600.0,
#                 1610900.0,
#                 1790200.0,
#                 4129900.0,
#                 1085900.0,
#                 1039900.0,
#                 1355400.0,
#                 1412300.0,
#                 1285900.0,
#                 3433900.0,
#                 3175400.0,
#                 435200.0,
#                 1187100.0
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "normal": {
#                     "show": false,
#                     "position": "top",
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "markPoint": {
#                 "data": [
#                     {
#                         "type": "max",
#                         "name": "Maximum",
#                         "symbol": "pin",
#                         "symbolSize": 50,
#                         "label": {
#                             "normal": {
#                                 "textStyle": {
#                                     "color": "#fff"
#                                 }
#                             }
#                         }
#                     },
#                     {
#                         "type": "min",
#                         "name": "Minimum",
#                         "symbol": "pin",
#                         "symbolSize": 50,
#                         "label": {
#                             "normal": {
#                                 "textStyle": {
#                                     "color": "#fff"
#                                 }
#                             }
#                         }
#                     }
#                 ]
#             },
#             "markLine": {
#                 "data": [
#                     {
#                         "type": "average",
#                         "name": "mean-Value"
#                     }
#                 ],
#                 "symbolSize": 10
#             },
#             "seriesId": 3622909
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u6295\u8d44\u91d1\u989d"
#             ],
#             "selectedMode": "multiple",
#             "show": true,
#             "left": "center",
#             "top": "top",
#             "orient": "horizontal",
#             "textStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "xAxis": [
#         {
#             "show": true,
#             "nameLocation": "middle",
#             "nameGap": 25,
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "inverse": false,
#             "boundaryGap": true,
#             "type": "category",
#             "splitLine": {
#                 "show": false
#             },
#             "axisLine": {
#                 "lineStyle": {
#                     "width": 1
#                 }
#             },
#             "axisLabel": {
#                 "interval": "auto",
#                 "rotate": 0,
#                 "margin": 8,
#                 "textStyle": {
#                     "fontSize": 12
#                 }
#             },
#             "data": [
#                 "08-01",
#                 "08-02",
#                 "08-03",
#                 "08-04",
#                 "08-05",
#                 "08-06",
#                 "08-07",
#                 "08-08",
#                 "08-09",
#                 "08-10",
#                 "08-11",
#                 "08-12",
#                 "08-13",
#                 "08-14",
#                 "08-15",
#                 "08-16",
#                 "08-17",
#                 "08-18",
#                 "08-19",
#                 "08-20"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "nameLocation": "middle",
#             "nameGap": 25,
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "inverse": false,
#             "boundaryGap": true,
#             "type": "value",
#             "splitLine": {
#                 "show": true
#             },
#             "axisLine": {
#                 "lineStyle": {
#                     "width": 1
#                 }
#             },
#             "axisLabel": {
#                 "interval": "auto",
#                 "formatter": "{value} ",
#                 "rotate": 0,
#                 "margin": 8,
#                 "textStyle": {
#                     "fontSize": 12
#                 }
#             }
#         }
#     ],
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597",
#         "#f6f5ec"
#     ]
# };
# myChart_44d3c567d14443819843cef30fd7c4f3.setOption(option_44d3c567d14443819843cef30fd7c4f3);
#
#     });
# </script>
