# %%
from IPython.display import display_html
display_html("""<button onclick="$('.input, .prompt, .output_stderr, .output_error').toggle();">点击隐藏代码</button>""", raw=True)
# Out:
# <button onclick="$('.input, .prompt, .output_stderr, .output_error').toggle();">点击隐藏代码</button>

# %% [markdown]
# **日报统计报表可视化**

# %%
from pyecharts import online

online() # needed for online viewing

# %%
from pyecharts import Bar


attr = ["8-1", "8-2", "8-3", "8-4", "8-5", "8-6"]
v1 = [5, 20, 36, 10, 75, 90]
v2 = [10, 25, 8, 60, 20, 80]
bar = Bar("注册人数示例")
bar.add("业务邀请", attr, v1, is_stack=True)
bar.add("普通邀请", attr, v2, is_stack=True)

bar
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': 'https://pyecharts.github.io/jupyter-echarts/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="4d08fbf7877d446581b91872034c3a5c" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_4d08fbf7877d446581b91872034c3a5c = echarts.init(document.getElementById('4d08fbf7877d446581b91872034c3a5c'), 'light', {renderer: 'canvas'});
#
# var option_4d08fbf7877d446581b91872034c3a5c = {
#     "title": [
#         {
#             "text": "\u6ce8\u518c\u4eba\u6570\u793a\u4f8b",
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
# ...

# %%
bar = Bar("投资人数示例")
bar.add("业务邀请", attr, v1, mark_point=["average"])
bar.add("普通邀请", attr, v2, mark_line=["min", "max"])

bar
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': 'https://pyecharts.github.io/jupyter-echarts/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="3320a35b59e44eb1aa6fc1591c19ec00" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_3320a35b59e44eb1aa6fc1591c19ec00 = echarts.init(document.getElementById('3320a35b59e44eb1aa6fc1591c19ec00'), 'light', {renderer: 'canvas'});
#
# var option_3320a35b59e44eb1aa6fc1591c19ec00 = {
#     "title": [
#         {
#             "text": "\u6295\u8d44\u4eba\u6570\u793a\u4f8b",
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
# ...

# %%
bar = Bar("券使用示例")
bar.add("抵用券", attr, v1)
bar.add("加息券", attr, v2, is_convert=True)

bar
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': 'https://pyecharts.github.io/jupyter-echarts/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="c3105d6f2ff74280988536b393671239" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_c3105d6f2ff74280988536b393671239 = echarts.init(document.getElementById('c3105d6f2ff74280988536b393671239'), 'light', {renderer: 'canvas'});
#
# var option_c3105d6f2ff74280988536b393671239 = {
#     "title": [
#         {
#             "text": "\u5238\u4f7f\u7528\u793a\u4f8b",
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
# ...

# %%
import random

attr = ["{}天".format(i) for i in range(30)]
v1 = [random.randint(1, 30) for _ in range(30)]
bar = Bar("投资金额示例")
bar.add("", attr, v1, is_label_show=True, is_datazoom_show=True)

bar
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': 'https://pyecharts.github.io/jupyter-echarts/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="3cb929dd935d44e7ae397ee57120d3e1" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_3cb929dd935d44e7ae397ee57120d3e1 = echarts.init(document.getElementById('3cb929dd935d44e7ae397ee57120d3e1'), 'light', {renderer: 'canvas'});
#
# var option_3cb929dd935d44e7ae397ee57120d3e1 = {
#     "title": [
#         {
#             "text": "\u6295\u8d44\u91d1\u989d\u793a\u4f8b",
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
# ...

# %%
from pyecharts import Funnel

attr = ["注册人数", "开通存管人数", "投资人数"]
value = [120, 80, 40]
funnel = Funnel("转化漏斗图示例")
funnel.add("商品", attr, value, is_label_show=True, label_pos="inside", label_text_color="#fff")

funnel
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': 'https://pyecharts.github.io/jupyter-echarts/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="860898b9af8443f0afe2ebce779e0959" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_860898b9af8443f0afe2ebce779e0959 = echarts.init(document.getElementById('860898b9af8443f0afe2ebce779e0959'), 'light', {renderer: 'canvas'});
#
# var option_860898b9af8443f0afe2ebce779e0959 = {
#     "title": [
#         {
#             "text": "\u8f6c\u5316\u6f0f\u6597\u56fe\u793a\u4f8b",
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
# ...

# %%
from pyecharts import Gauge

gauge = Gauge("投资匹配率示例")
gauge.add("投资匹配率", "已匹配率", 66.66)

gauge
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': 'https://pyecharts.github.io/jupyter-echarts/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="53d4c8304a4f43faa332b6a57a2775f7" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_53d4c8304a4f43faa332b6a57a2775f7 = echarts.init(document.getElementById('53d4c8304a4f43faa332b6a57a2775f7'), 'light', {renderer: 'canvas'});
#
# var option_53d4c8304a4f43faa332b6a57a2775f7 = {
#     "title": [
#         {
#             "text": "\u6295\u8d44\u5339\u914d\u7387\u793a\u4f8b",
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
# ...

# %%
attr = ["60后", "70后", "80后", "90后"]
v2 = [19, 21, 32, 20]
pie = Pie("投资人年龄比例示例", title_pos='center', width=900)
pie.add("商品B", attr, v2, center=[50, 50], is_random=True, radius=[30, 75], rosetype='area',
        is_legend_show=False, is_label_show=True)

pie
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': 'https://pyecharts.github.io/jupyter-echarts/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="6e9ef11f9df14bb59d4746621024c72a" style="width:900px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_6e9ef11f9df14bb59d4746621024c72a = echarts.init(document.getElementById('6e9ef11f9df14bb59d4746621024c72a'), 'light', {renderer: 'canvas'});
#
# var option_6e9ef11f9df14bb59d4746621024c72a = {
#     "title": [
#         {
#             "text": "\u6295\u8d44\u4eba\u5e74\u9f84\u6bd4\u4f8b\u793a\u4f8b",
#             "left": "center",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
# ...

# %%
from pyecharts import Bar, Line, Scatter, EffectScatter, Grid  

attr = ["衬衫", "羊毛衫", "雪纺衫", "裤子", "高跟鞋", "袜子"]
v1 = [5, 20, 36, 10, 75, 90]
v2 = [10, 25, 8, 60, 20, 80]
bar = Bar("柱状图示例", height=720, width=1200, title_pos="65%")
bar.add("商家A", attr, v1, is_stack=True)
bar.add("商家B", attr, v2, is_stack=True, legend_pos="80%")
line = Line("折线图示例")
attr = ['周一', '周二', '周三', '周四', '周五', '周六', '周日']
line.add("最高气温", attr, [11, 11, 15, 13, 12, 13, 10], mark_point=["max", "min"], mark_line=["average"])
line.add("最低气温", attr, [1, -2, 2, 5, 3, 2, 0], mark_point=["max", "min"],
         mark_line=["average"], legend_pos="20%")
v1 = [5, 20, 36, 10, 75, 90]
v2 = [10, 25, 8, 60, 20, 80]
scatter = Scatter("散点图示例", title_top="50%", title_pos="65%")
scatter.add("scatter", v1, v2, legend_top="50%", legend_pos="80%")
es = EffectScatter("动态散点图示例", title_top="50%")
es.add("es", [11, 11, 15, 13, 12, 13, 10], [1, -2, 2, 5, 3, 2, 0], effect_scale=6,
        legend_top="50%", legend_pos="20%")

grid = Grid()
grid.add(bar, grid_bottom="60%", grid_left="60%")
grid.add(line, grid_bottom="60%", grid_right="60%")
grid.add(scatter, grid_top="60%", grid_left="60%")
grid.add(es, grid_top="60%", grid_right="60%")

grid
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': 'https://pyecharts.github.io/jupyter-echarts/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="79b11a14d22a40f8a08bea4fc62810e6" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_79b11a14d22a40f8a08bea4fc62810e6 = echarts.init(document.getElementById('79b11a14d22a40f8a08bea4fc62810e6'), 'light', {renderer: 'canvas'});
#
# var option_79b11a14d22a40f8a08bea4fc62810e6 = {
#     "title": [
#         {
#             "text": "\u67f1\u72b6\u56fe\u793a\u4f8b",
#             "left": "65%",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         },
#         {
#             "text": "\u6298\u7ebf\u56fe\u793a\u4f8b",
#             "left": "auto",
#             "top": "auto",
# ...

# %%
from pyecharts import Bar, Timeline

from random import randint

attr = ["普通邀请", "业务邀请", "自主注册", "推广渠道"]
bar_1 = Bar("2014 年", "数据纯属虚构")
bar_1.add("春季", attr, [randint(10, 100) for _ in range(4)])
bar_1.add("夏季", attr, [randint(10, 100) for _ in range(4)])
bar_1.add("秋季", attr, [randint(10, 100) for _ in range(4)])
bar_1.add("冬季", attr, [randint(10, 100) for _ in range(4)])

bar_2 = Bar("2015 年", "数据纯属虚构")
bar_2.add("春季", attr, [randint(10, 100) for _ in range(4)])
bar_2.add("夏季", attr, [randint(10, 100) for _ in range(4)])
bar_2.add("秋季", attr, [randint(10, 100) for _ in range(4)])
bar_2.add("冬季", attr, [randint(10, 100) for _ in range(4)])

bar_3 = Bar("2016 年", "数据纯属虚构")
bar_3.add("春季", attr, [randint(10, 100) for _ in range(4)])
bar_3.add("夏季", attr, [randint(10, 100) for _ in range(4)])
bar_3.add("秋季", attr, [randint(10, 100) for _ in range(4)])
bar_3.add("冬季", attr, [randint(10, 100) for _ in range(4)])

bar_4 = Bar("2017 年", "数据纯属虚构")
bar_4.add("春季", attr, [randint(10, 100) for _ in range(4)])
bar_4.add("夏季", attr, [randint(10, 100) for _ in range(4)])
bar_4.add("秋季", attr, [randint(10, 100) for _ in range(4)])
bar_4.add("冬季", attr, [randint(10, 100) for _ in range(4)])

bar_5 = Bar("2018 年", "数据纯属虚构")
bar_5.add("春季", attr, [randint(10, 100) for _ in range(4)])
bar_5.add("夏季", attr, [randint(10, 100) for _ in range(4)])
bar_5.add("秋季", attr, [randint(10, 100) for _ in range(4)])
bar_5.add("冬季", attr, [randint(10, 100) for _ in range(4)], is_legend_show=True)

timeline = Timeline(is_auto_play=True, timeline_bottom=0)
timeline.add(bar_1, '2014 年')
timeline.add(bar_2, '2015 年')
timeline.add(bar_3, '2016 年')
timeline.add(bar_4, '2017 年')
timeline.add(bar_5, '2018 年')

timeline
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': 'https://pyecharts.github.io/jupyter-echarts/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="4b45f695623a4487b19143ee5b5c0ba2" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_4b45f695623a4487b19143ee5b5c0ba2 = echarts.init(document.getElementById('4b45f695623a4487b19143ee5b5c0ba2'), 'light', {renderer: 'canvas'});
#
# var option_4b45f695623a4487b19143ee5b5c0ba2 = {
#     "baseOption": {
#         "timeline": {
#             "axisType": "category",
#             "autoPlay": true,
#             "loop": true,
#             "rewind": false,
#             "show": true,
#             "symbol": "emptyCircle",
#             "symbolSize": 10,
#             "playInterval": 2000,
#             "left": "auto",
#             "right": "auto",
#             "top": "auto",
#             "bottom": 0,
#             "data": [
# ...
