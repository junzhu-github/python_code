# %%
from IPython.display import display_html
display_html("""<button onclick="$('.input, .prompt, .output_stderr, .output_error').toggle();">显示代码</button>""", raw=True)
# Out:
# <button onclick="$('.input, .prompt, .output_stderr, .output_error').toggle();">显示代码</button>

# %%
#coding=utf-8
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from pyecharts import online
from pyecharts import Bar
# %matplotlib inline
online()

# %%
os.chdir('D:\OneDrive\python\data')

# %%
with pd.ExcelFile('注册.xlsx') as xlsx:
    df_zhuce = pd.read_excel(xlsx,'注册')
    df_kaitong = pd.read_excel(xlsx,'开通')
    df_touzi = pd.read_excel(xlsx,'投资')

# %%
df_zhuce['注册日期'] = pd.to_datetime(df_zhuce['注册时间']).dt.strftime('%m-%d')

# %%
zhuce_num = df_zhuce.groupby('注册日期')['用户名'].count()

# %% [markdown]
# # 一、注册统计

# %% [markdown]
# # 1.注册人数

# %%
attr = zhuce_num.index
v1 = zhuce_num.values
bar = Bar("每日注册","2018-08")
bar.add('注册人数',attr,v1,mark_line=["average"],mark_point=["max", "min"])
bar
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': 'https://pyecharts.github.io/jupyter-echarts/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="bde55034ee894b868ddda3a5ca6ac8a4" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_bde55034ee894b868ddda3a5ca6ac8a4 = echarts.init(document.getElementById('bde55034ee894b868ddda3a5ca6ac8a4'), 'light', {renderer: 'canvas'});
#
# var option_bde55034ee894b868ddda3a5ca6ac8a4 = {
#     "title": [
#         {
#             "text": "\u6bcf\u65e5\u6ce8\u518c",
#             "subtext": "2018-08",
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "\u4e0b\u8f7d\u56fe\u7247"
#             },
#             "restore": {
#                 "show": true
#             },
#             "dataView": {
#                 "show": true
#             }
#         }
#     },
#     "series_id": 5592347,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "borderWidth": 0
#     },
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u6ce8\u518c\u4eba\u6570",
#             "data": [
#                 49.0,
#                 25.0,
#                 49.0,
#                 38.0,
#                 26.0,
#                 48.0,
#                 81.0,
#                 108.0,
#                 58.0,
#                 56.0,
#                 32.0,
#                 54.0,
#                 79.0,
#                 130.0,
#                 53.0
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "normal": {
#                     "show": false,
#                     "position": "top",
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "markPoint": {
#                 "data": [
#                     {
#                         "type": "max",
#                         "name": "Maximum",
#                         "symbol": "pin",
#                         "symbolSize": 50,
#                         "label": {
#                             "normal": {
#                                 "textStyle": {
#                                     "color": "#fff"
#                                 }
#                             }
#                         }
#                     },
#                     {
#                         "type": "min",
#                         "name": "Minimum",
#                         "symbol": "pin",
#                         "symbolSize": 50,
#                         "label": {
#                             "normal": {
#                                 "textStyle": {
#                                     "color": "#fff"
#                                 }
#                             }
#                         }
#                     }
#                 ]
#             },
#             "markLine": {
#                 "data": [
#                     {
#                         "type": "average",
#                         "name": "mean-Value"
#                     }
#                 ],
#                 "symbolSize": 10
#             },
#             "seriesId": 5592347
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u6ce8\u518c\u4eba\u6570"
#             ],
#             "selectedMode": "multiple",
#             "show": true,
#             "left": "center",
#             "top": "top",
#             "orient": "horizontal",
#             "textStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "xAxis": [
#         {
#             "show": true,
#             "nameLocation": "middle",
#             "nameGap": 25,
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "inverse": false,
#             "boundaryGap": true,
#             "type": "category",
#             "splitLine": {
#                 "show": false
#             },
#             "axisLine": {
#                 "lineStyle": {
#                     "width": 1
#                 }
#             },
#             "axisLabel": {
#                 "interval": "auto",
#                 "rotate": 0,
#                 "margin": 8,
#                 "textStyle": {
#                     "fontSize": 12
#                 }
#             },
#             "data": [
#                 "08-01",
#                 "08-02",
#                 "08-03",
#                 "08-04",
#                 "08-05",
#                 "08-06",
#                 "08-07",
#                 "08-08",
#                 "08-09",
#                 "08-10",
#                 "08-11",
#                 "08-12",
#                 "08-13",
#                 "08-14",
#                 "08-15"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "nameLocation": "middle",
#             "nameGap": 25,
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "inverse": false,
#             "boundaryGap": true,
#             "type": "value",
#             "splitLine": {
#                 "show": true
#             },
#             "axisLine": {
#                 "lineStyle": {
#                     "width": 1
#                 }
#             },
#             "axisLabel": {
#                 "interval": "auto",
#                 "formatter": "{value} ",
#                 "rotate": 0,
#                 "margin": 8,
#                 "textStyle": {
#                     "fontSize": 12
#                 }
#             }
#         }
#     ],
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597",
#         "#f6f5ec"
#     ]
# };
# myChart_bde55034ee894b868ddda3a5ca6ac8a4.setOption(option_bde55034ee894b868ddda3a5ca6ac8a4);
#
#     });
# </script>

# %% [markdown]
# ## 2、各邀请渠道注册人数

# %%
s_yw = df_zhuce[df_zhuce['邀请渠道'] == '业务邀请'].groupby('注册日期')['用户名'].count()
s_pt = df_zhuce[df_zhuce['邀请渠道'] == '普通邀请'].groupby('注册日期')['用户名'].count()
s_zz = df_zhuce[df_zhuce['邀请渠道'] == '自主注册'].groupby('注册日期')['用户名'].count()

# %%
df_yw = pd.DataFrame(s_yw,index=zhuce_num.index).fillna(0)
df_pt = pd.DataFrame(s_pt,index=zhuce_num.index).fillna(0)
df_zz = pd.DataFrame(s_zz,index=zhuce_num.index).fillna(0)

# %%
attr = zhuce_num.index
v1 = df_yw['用户名']
v2 = df_pt['用户名']
v3 = df_zz['用户名']

bar = Bar("8月注册数","按邀请渠道统计")
bar.add('业务邀请',attr,v1,mark_line=["average"],mark_point=["max", "min"])
bar.add('普通邀请',attr,v2,mark_line=["average"],mark_point=["max", "min"])
bar.add('自主注册',attr,v3,mark_line=["average"],mark_point=["max", "min"])
bar
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': 'https://pyecharts.github.io/jupyter-echarts/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="96ddfe88f19a476eb9daf31271d311c8" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_96ddfe88f19a476eb9daf31271d311c8 = echarts.init(document.getElementById('96ddfe88f19a476eb9daf31271d311c8'), 'light', {renderer: 'canvas'});
#
# var option_96ddfe88f19a476eb9daf31271d311c8 = {
#     "title": [
#         {
#             "text": "8\u6708\u6ce8\u518c\u6570",
#             "subtext": "\u6309\u9080\u8bf7\u6e20\u9053\u7edf\u8ba1",
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "\u4e0b\u8f7d\u56fe\u7247"
#             },
#             "restore": {
#                 "show": true
#             },
#             "dataView": {
#                 "show": true
#             }
#         }
#     },
#     "series_id": 6467309,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "borderWidth": 0
#     },
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u4e1a\u52a1\u9080\u8bf7",
#             "data": [
#                 37.0,
#                 13.0,
#                 44.0,
#                 29.0,
#                 16.0,
#                 37.0,
#                 64.0,
#                 98.0,
#                 43.0,
#                 51.0,
#                 24.0,
#                 45.0,
#                 68.0,
#                 119.0,
#                 40.0
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "normal": {
#                     "show": false,
#                     "position": "top",
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "markPoint": {
#                 "data": [
#                     {
#                         "type": "max",
#                         "name": "Maximum",
#                         "symbol": "pin",
#                         "symbolSize": 50,
#                         "label": {
#                             "normal": {
#                                 "textStyle": {
#                                     "color": "#fff"
#                                 }
#                             }
#                         }
#                     },
#                     {
#                         "type": "min",
#                         "name": "Minimum",
#                         "symbol": "pin",
#                         "symbolSize": 50,
#                         "label": {
#                             "normal": {
#                                 "textStyle": {
#                                     "color": "#fff"
#                                 }
#                             }
#                         }
#                     }
#                 ]
#             },
#             "markLine": {
#                 "data": [
#                     {
#                         "type": "average",
#                         "name": "mean-Value"
#                     }
#                 ],
#                 "symbolSize": 10
#             },
#             "seriesId": 6467309
#         },
#         {
#             "type": "bar",
#             "name": "\u666e\u901a\u9080\u8bf7",
#             "data": [
#                 2.0,
#                 4.0,
#                 0.0,
#                 2.0,
#                 2.0,
#                 2.0,
#                 9.0,
#                 3.0,
#                 4.0,
#                 0.0,
#                 3.0,
#                 0.0,
#                 1.0,
#                 2.0,
#                 1.0
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "normal": {
#                     "show": false,
#                     "position": "top",
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "markPoint": {
#                 "data": [
#                     {
#                         "type": "max",
#                         "name": "Maximum",
#                         "symbol": "pin",
#                         "symbolSize": 50,
#                         "label": {
#                             "normal": {
#                                 "textStyle": {
#                                     "color": "#fff"
#                                 }
#                             }
#                         }
#                     },
#                     {
#                         "type": "min",
#                         "name": "Minimum",
#                         "symbol": "pin",
#                         "symbolSize": 50,
#                         "label": {
#                             "normal": {
#                                 "textStyle": {
#                                     "color": "#fff"
#                                 }
#                             }
#                         }
#                     }
#                 ]
#             },
#             "markLine": {
#                 "data": [
#                     {
#                         "type": "average",
#                         "name": "mean-Value"
#                     }
#                 ],
#                 "symbolSize": 10
#             },
#             "seriesId": 6467309
#         },
#         {
#             "type": "bar",
#             "name": "\u81ea\u4e3b\u6ce8\u518c",
#             "data": [
#                 10.0,
#                 8.0,
#                 5.0,
#                 7.0,
#                 8.0,
#                 9.0,
#                 8.0,
#                 7.0,
#                 11.0,
#                 5.0,
#                 5.0,
#                 9.0,
#                 10.0,
#                 9.0,
#                 12.0
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "normal": {
#                     "show": false,
#                     "position": "top",
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "markPoint": {
#                 "data": [
#                     {
#                         "type": "max",
#                         "name": "Maximum",
#                         "symbol": "pin",
#                         "symbolSize": 50,
#                         "label": {
#                             "normal": {
#                                 "textStyle": {
#                                     "color": "#fff"
#                                 }
#                             }
#                         }
#                     },
#                     {
#                         "type": "min",
#                         "name": "Minimum",
#                         "symbol": "pin",
#                         "symbolSize": 50,
#                         "label": {
#                             "normal": {
#                                 "textStyle": {
#                                     "color": "#fff"
#                                 }

# %% [markdown]
# # 二、投资统计

# %%
with pd.ExcelFile('投资.xlsx') as xlsx:
    df_touzi = pd.read_excel(xlsx,'投资记录')

# %%
df_touzi['投资日期'] = pd.to_datetime(df_touzi['投资时间']).dt.strftime('%m-%d')

# %%
touzi_money = df_touzi.groupby('投资日期')['总投资金额'].sum()

# %%
attr = touzi_money.index
v1 = touzi_money.values
bar = Bar("每日投资","2018-08")
bar.add('投资金额',attr,v1,mark_line=["average"],mark_point=["max", "min"])
bar
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': 'https://pyecharts.github.io/jupyter-echarts/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="188356e5cf3d42fc91fc6d54e980af01" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_188356e5cf3d42fc91fc6d54e980af01 = echarts.init(document.getElementById('188356e5cf3d42fc91fc6d54e980af01'), 'light', {renderer: 'canvas'});
#
# var option_188356e5cf3d42fc91fc6d54e980af01 = {
#     "title": [
#         {
#             "text": "\u6bcf\u65e5\u6295\u8d44",
#             "subtext": "2018-08",
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "\u4e0b\u8f7d\u56fe\u7247"
#             },
#             "restore": {
#                 "show": true
#             },
#             "dataView": {
#                 "show": true
#             }
#         }
#     },
#     "series_id": 2906147,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "borderWidth": 0
#     },
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u6295\u8d44\u91d1\u989d",
#             "data": [
#                 1262300.0,
#                 1718400.0,
#                 1334200.0,
#                 1002200.0,
#                 852100.0,
#                 1232500.0,
#                 2172500.0,
#                 2143600.0,
#                 1610900.0,
#                 1790200.0,
#                 4129900.0,
#                 1085900.0,
#                 1039900.0,
#                 1355400.0,
#                 1412300.0,
#                 1285900.0,
#                 3433900.0,
#                 3175400.0,
#                 435200.0,
#                 1187100.0
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "normal": {
#                     "show": false,
#                     "position": "top",
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "markPoint": {
#                 "data": [
#                     {
#                         "type": "max",
#                         "name": "Maximum",
#                         "symbol": "pin",
#                         "symbolSize": 50,
#                         "label": {
#                             "normal": {
#                                 "textStyle": {
#                                     "color": "#fff"
#                                 }
#                             }
#                         }
#                     },
#                     {
#                         "type": "min",
#                         "name": "Minimum",
#                         "symbol": "pin",
#                         "symbolSize": 50,
#                         "label": {
#                             "normal": {
#                                 "textStyle": {
#                                     "color": "#fff"
#                                 }
#                             }
#                         }
#                     }
#                 ]
#             },
#             "markLine": {
#                 "data": [
#                     {
#                         "type": "average",
#                         "name": "mean-Value"
#                     }
#                 ],
#                 "symbolSize": 10
#             },
#             "seriesId": 2906147
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u6295\u8d44\u91d1\u989d"
#             ],
#             "selectedMode": "multiple",
#             "show": true,
#             "left": "center",
#             "top": "top",
#             "orient": "horizontal",
#             "textStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "xAxis": [
#         {
#             "show": true,
#             "nameLocation": "middle",
#             "nameGap": 25,
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "inverse": false,
#             "boundaryGap": true,
#             "type": "category",
#             "splitLine": {
#                 "show": false
#             },
#             "axisLine": {
#                 "lineStyle": {
#                     "width": 1
#                 }
#             },
#             "axisLabel": {
#                 "interval": "auto",
#                 "rotate": 0,
#                 "margin": 8,
#                 "textStyle": {
#                     "fontSize": 12
#                 }
#             },
#             "data": [
#                 "08-01",
#                 "08-02",
#                 "08-03",
#                 "08-04",
#                 "08-05",
#                 "08-06",
#                 "08-07",
#                 "08-08",
#                 "08-09",
#                 "08-10",
#                 "08-11",
#                 "08-12",
#                 "08-13",
#                 "08-14",
#                 "08-15",
#                 "08-16",
#                 "08-17",
#                 "08-18",
#                 "08-19",
#                 "08-20"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "nameLocation": "middle",
#             "nameGap": 25,
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "inverse": false,
#             "boundaryGap": true,
#             "type": "value",
#             "splitLine": {
#                 "show": true
#             },
#             "axisLine": {
#                 "lineStyle": {
#                     "width": 1
#                 }
#             },
#             "axisLabel": {
#                 "interval": "auto",
#                 "formatter": "{value} ",
#                 "rotate": 0,
#                 "margin": 8,
#                 "textStyle": {
#                     "fontSize": 12
#                 }
#             }
#         }
#     ],
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597",
#         "#f6f5ec"
#     ]
# };
# myChart_188356e5cf3d42fc91fc6d54e980af01.setOption(option_188356e5cf3d42fc91fc6d54e980af01);
#
#     });
# </script>
